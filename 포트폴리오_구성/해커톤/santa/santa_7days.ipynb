# %% [markdown]
# ### 필요 라이브러리 호출

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import yfinance as yf

from scipy.stats import ttest_ind, mannwhitneyu
import statsmodels.api as sm

import seaborn as sns
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Darwin': # MAC
    plt.rc('font', family='AppleGothic')
else: # Windows
    plt.rc('font', family='Malgun Gothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
import utils
import preprocessing

# %% [markdown]
# ### 데이터 수집

# %%
name = 'KOSPI'
symbol = '117460.KS'

# ohlcv 데이터 수집 (전체 기간)
data = preprocessing.get_data(symbol)

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close  Volume  \
# Date
# 2009-10-13   7800.0   7800.0   7630.0   7710.0   6968.276367       0
# 2009-10-14   7730.0   7885.0   7715.0   7790.0   7040.580078       0
# 2009-10-15   7830.0   7860.0   7775.0   7805.0   7054.136719       0
# 2009-10-16   7805.0   7860.0   7725.0   7730.0   6986.352539       0
# 2009-10-19   7800.0   7800.0   7630.0   7760.0   7013.466797       0
# ...             ...      ...      ...      ...           ...     ...
# 2023-12-28  15825.0  16005.0  15795.0  15975.0  15975.000000    4977
# 2024-01-02  16000.0  16000.0  15825.0  15905.0  15905.000000   42973
# 2024-01-03  15730.0  15730.0  15545.0  15545.0  15545.000000   12038
# 2024-01-04  15315.0  15650.0  15270.0  15565.0  15565.000000    1746
# 2024-01-05  15465.0  15760.0  15465.0  15615.0  15615.000000    5082
#
#                  rtn  event  귀속년도
# Date
# 2009-10-13 -1.153847   else  2009
# 2009-10-14  1.037613   else  2009
# 2009-10-15  0.192550   else  2009
# 2009-10-16 -0.960914   else  2009
# 2009-10-19  0.388103   else  2009
# ...              ...    ...   ...
# 2023-12-28  0.947867  santa  2023
# 2024-01-02 -0.438185  santa  2023
# 2024-01-03 -2.263439  santa  2023
# 2024-01-04  0.128659  after  2023
# 2024-01-05  0.321234  after  2023
#
# [3483 rows x 9 columns]

# %%
# 일일수익률 계산
data = utils.create_rtn(data, col_rtn='rtn')
data
# Out:
#                Open     High      Low    Close     Adj Close  Volume  \
# Date
# 2009-10-14   7730.0   7885.0   7715.0   7790.0   7040.580078       0
# 2009-10-15   7830.0   7860.0   7775.0   7805.0   7054.136719       0
# 2009-10-16   7805.0   7860.0   7725.0   7730.0   6986.352539       0
# 2009-10-19   7800.0   7800.0   7630.0   7760.0   7013.466797       0
# 2009-10-20   7760.0   7840.0   7745.0   7800.0   7049.618164       0
# ...             ...      ...      ...      ...           ...     ...
# 2023-12-28  15825.0  16005.0  15795.0  15975.0  15975.000000    4977
# 2024-01-02  16000.0  16000.0  15825.0  15905.0  15905.000000   42973
# 2024-01-03  15730.0  15730.0  15545.0  15545.0  15545.000000   12038
# 2024-01-04  15315.0  15650.0  15270.0  15565.0  15565.000000    1746
# 2024-01-05  15465.0  15760.0  15465.0  15615.0  15615.000000    5082
#
#                  rtn  event  귀속년도
# Date
# 2009-10-14  1.037613   else  2009
# 2009-10-15  0.192550   else  2009
# 2009-10-16 -0.960914   else  2009
# 2009-10-19  0.388103   else  2009
# 2009-10-20  0.515456   else  2009
# ...              ...    ...   ...
# 2023-12-28  0.947867  santa  2023
# 2024-01-02 -0.438185  santa  2023
# 2024-01-03 -2.263439  santa  2023
# 2024-01-04  0.128659  after  2023
# 2024-01-05  0.321234  after  2023
#
# [3482 rows x 9 columns]

# %% [markdown]
# #### 데이터 기간 설정

# %%
date_start = '2010-01-01'
date_end = '2023-12-31'

df = utils.filter_date(data, date_start, date_end)
df
# Out:
#                Open     High      Low    Close     Adj Close  Volume  \
# Date
# 2010-01-04   8200.0   8235.0   8185.0   8200.0   7411.137207    3553
# 2010-01-05   8300.0   8340.0   8265.0   8280.0   7483.440918   41826
# 2010-01-06   8350.0   8450.0   8350.0   8430.0   7619.010254   15584
# 2010-01-07   8500.0   8505.0   8320.0   8325.0   7524.111328    7621
# 2010-01-08   8325.0   8420.0   8210.0   8420.0   7609.973145    6423
# ...             ...      ...      ...      ...           ...     ...
# 2023-12-21  16265.0  16265.0  15945.0  16080.0  16080.000000    4749
# 2023-12-22  16250.0  16250.0  15830.0  15835.0  15835.000000   12737
# 2023-12-26  15835.0  15835.0  15610.0  15680.0  15680.000000    4923
# 2023-12-27  15660.0  15940.0  15660.0  15825.0  15825.000000   11190
# 2023-12-28  15825.0  16005.0  15795.0  15975.0  15975.000000    4977
#
#                  rtn  event  귀속년도
# Date
# 2010-01-04  0.000000  santa  2009
# 2010-01-05  0.975609  santa  2009
# 2010-01-06  1.811591  after  2009
# 2010-01-07 -1.245555  after  2009
# 2010-01-08  1.141156  after  2009
# ...              ...    ...   ...
# 2023-12-21 -1.470588  santa  2023
# 2023-12-22 -1.523632  santa  2023
# 2023-12-26 -0.978844  santa  2023
# 2023-12-27  0.924745  santa  2023
# 2023-12-28  0.947867  santa  2023
#
# [3425 rows x 9 columns]

# %% [markdown]
# #### 최종 데이터 정보(요약통계량)

# %%
df.head()
# Out:
#               Open    High     Low   Close    Adj Close  Volume       rtn  \
# Date
# 2010-01-04  8200.0  8235.0  8185.0  8200.0  7411.137207    3553  0.000000
# 2010-01-05  8300.0  8340.0  8265.0  8280.0  7483.440918   41826  0.975609
# 2010-01-06  8350.0  8450.0  8350.0  8430.0  7619.010254   15584  1.811591
# 2010-01-07  8500.0  8505.0  8320.0  8325.0  7524.111328    7621 -1.245555
# 2010-01-08  8325.0  8420.0  8210.0  8420.0  7609.973145    6423  1.141156
#
#             event  귀속년도
# Date
# 2010-01-04  santa  2009
# 2010-01-05  santa  2009
# 2010-01-06  after  2009
# 2010-01-07  after  2009
# 2010-01-08  after  2009

# %%
df.tail()
# Out:
#                Open     High      Low    Close  Adj Close  Volume       rtn  \
# Date
# 2023-12-21  16265.0  16265.0  15945.0  16080.0    16080.0    4749 -1.470588
# 2023-12-22  16250.0  16250.0  15830.0  15835.0    15835.0   12737 -1.523632
# 2023-12-26  15835.0  15835.0  15610.0  15680.0    15680.0    4923 -0.978844
# 2023-12-27  15660.0  15940.0  15660.0  15825.0    15825.0   11190  0.924745
# 2023-12-28  15825.0  16005.0  15795.0  15975.0    15975.0    4977  0.947867
#
#             event  귀속년도
# Date
# 2023-12-21  santa  2023
# 2023-12-22  santa  2023
# 2023-12-26  santa  2023
# 2023-12-27  santa  2023
# 2023-12-28  santa  2023

# %%
df[['rtn']].describe()
# Out:
#                rtn
# count  3425.000000
# mean      0.037183
# std       1.717301
# min     -14.607559
# 25%      -0.848600
# 50%       0.032148
# 75%       0.919840
# max      13.446806

# %% [markdown]
# ## 산타랠리 비교

# %%
df['event'].value_counts()
# Out:
# event
# else      3131
# santa       98
# after       98
# before      98
# Name: count, dtype: int64

# %%
rtns_santa = df[df['event']=='santa']['rtn']
rtns_before = df[df['event']=='before']['rtn']

rtns_santa.shape, rtns_before.shape
# Out:
# ((98,), (98,))

# %% [markdown]
# ### 일 평균 수익률 비교

# %%
df.groupby('event')[['rtn']].agg(['mean', 'std', 'min', 'max', 'count'])
# Out:
#              rtn
#             mean       std        min        max count
# event
# after   0.228244  1.599201  -3.636365   4.233654    98
# before  0.201307  1.449956  -4.438853   4.575838    98
# else    0.018410  1.737280 -14.607559  13.446806  3131
# santa   0.281789  1.384107  -3.301052   6.593725    98

# %% [markdown]
# ### T-Test & Mann-Whitney U Test

# %%
res_test = pd.DataFrame(
    columns = ['T-Test', 'mann-Whitney U Test'],
    index = ['Statistic', 'p-value']
)

# %%
res_ttest = ttest_ind(
    rtns_santa, rtns_before,
    equal_var=True, alternative='greater'
)
t_statistic = res_ttest.statistic
t_pvalue = res_ttest.pvalue
# t_df = int(res_ttest.df)

res_test['T-Test'] = [t_statistic, t_pvalue]
res_test
# Out:
#              T-Test mann-Whitney U Test
# Statistic  0.397468                 NaN
# p-value    0.345730                 NaN

# %%
t_pvalue
# Out:
# 0.3457295111905829

# %%
res_utest = mannwhitneyu(
    rtns_santa, rtns_before,
    alternative='greater'
)
u_statistic = res_utest.statistic
u_pvalue = res_utest.pvalue

res_test['mann-Whitney U Test'] = [u_statistic, u_pvalue]

# %%
res_test
# Out:
#              T-Test  mann-Whitney U Test
# Statistic  0.397468          4890.500000
# p-value    0.345730             0.412303
